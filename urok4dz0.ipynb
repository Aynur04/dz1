# %% [markdown]
# <a href="https://colab.research.google.com/github/Aynur04/dz1/blob/main/urok4dz0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Условие 1: Задача 1**
#
# Постройте график
#
# Назовите график
#
# Сделайте именование оси x и оси y
#
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc-house-data и laptop_price
#
# 1.2. Изучите стоимости недвижимости
#
# 1.3. Изучите распределение квадратуры жилой
#
# 1.4. Изучите распределение года постройки

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=50, color='blue', edgecolor='black')
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Стоимость, $')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Стоимость большинства домов находится в пределах от 200 тысяч до 800 тысяч долларов. Есть небольшое количество домов, стоимость которых превышает 2 миллиона долларов.

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['sqft_living'], bins=50, color='green', edgecolor='black')
plt.title('Распределение жилой площади')
plt.xlabel('Площадь, кв.')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Жилая площадь большинства домов варьируется от 1,000 до 3,000 квадратных футов. Есть несколько домов с жилой площадью более 4,000 квадратных футов.

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['yr_built'], bins=50, color='purple', edgecolor='black')
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Большинство домов были построены в 1950-2000 годах. Есть дома, построенные в начале 1900-х годов и несколько современных домов, построенных после 2000 года.

# %% [markdown]
# **Условие 2: 2 задача**
#
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы
#
# 2.2. Изучите распределение этажей домов
#
# 2.3. Изучите распределение состояния домов

# %%
waterfront_counts = df['waterfront'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(waterfront_counts, labels=['No Waterfront', 'Waterfront'], autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen'])
plt.title('Распределение домов по наличию вида на набережную')
plt.show()

# %% [markdown]
# **Вывод** Большинство домов не имеют вида на набережную. Дома с видом на набережную составляют небольшую часть от общего количества недвижимости.

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
floors_counts = df['floors'].value_counts()

plt.figure(figsize=(10, 6))
floors_counts.plot(kind='bar', color='green')
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Большинство домов имеют один или два этажа. Меньшая часть домов имеет три или более этажей.

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
condition_counts = df['condition'].value_counts()

plt.figure(figsize=(10, 6))
condition_counts.plot(kind='bar', color='purple')
plt.title('Распределение состояния домов')
plt.xlabel('Состояние дома (от 1 до 5)')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Большинство домов находятся в хорошем состоянии (оценка 3). Меньшая часть домов имеет оценку состояния 4 или 5, что означает отличное состояние. Очень мало домов имеют плохое состояние (оценка 1 или 2).

# %% [markdown]
# **Условие 3: 3 задача**
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%dT%H%M%S')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['sqft_living'], y=df['price'])
plt.title('Влияние жилой площади на стоимость недвижимости')
plt.xlabel('Жилая площадь (кв. футы)')
plt.ylabel('Стоимость ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Мы видим положительную корреляцию между жилой площадью и стоимостью недвижимости: с увеличением жилой площади увеличивается и стоимость

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['bedrooms'], y=df['price'])
plt.title('Влияние количества спален на стоимость недвижимости')
plt.xlabel('Количество спален')
plt.ylabel('Стоимость ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** На графике видно, что количество спален оказывает влияние на стоимость недвижимости, но после определенного количества спален влияние становится менее выраженным

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['condition'], y=df['price'])
plt.title('Влияние состояния дома на стоимость недвижимости')
plt.xlabel('Состояние дома')
plt.ylabel('Стоимость ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Состояние дома также оказывает влияние на его стоимость: дома в лучшем состоянии имеют тенденцию стоить дороже.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='waterfront', y='price', data=df, palette='coolwarm')
plt.title('Цена vs. Наличие вида на набережную')
plt.xlabel('Вид на набережную')
plt.ylabel('Цена ($)')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()
# Out:
# <ipython-input-23-3df652fbb21b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='waterfront', y='price', data=df, palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['yr_built'], y=df['price'])
plt.title('Влияние года постройки на стоимость недвижимости')
plt.xlabel('Год постройки')
plt.ylabel('Стоимость ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# **Вывод** Год постройки: Год постройки оказывает влияние на стоимость, но это влияние менее значительное по сравнению с другими факторами

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='floors', y='price', data=df, palette='viridis')
plt.title('Цена vs. Этажи')
plt.xlabel('Количество этажей')
plt.ylabel('Цена ($)')
plt.show()
# Out:
# <ipython-input-24-0a2e09017c73>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='floors', y='price', data=df, palette='viridis')

# %% [markdown]
# **Вывод** Боксплот показывает, что дома с большим количеством этажей имеют тенденцию быть дороже. Дома с 1 этажом, как правило, дешевле

# %%
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(16, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# На тепловой карте корреляции можно увидеть следующие ключевые моменты:
#
# 1.   Цена и площадь:
#
# *   price (цена) имеет высокую положительную корреляцию с sqft_living (жилая площадь) и grade (оценка качества дома), что логично, так как более большие и качественные дома обычно стоят дороже.
# *   price также имеет заметную корреляцию с sqft_above (площадь надземной части) и bathrooms (количество ванных комнат).
#
#
# 2.   Жилая площадь и оценка:
#
# *   sqft_living (жилая площадь) и grade (оценка) имеют сильную положительную корреляцию, что указывает на то, что более просторные дома часто имеют более высокую оценку.
#
# 3.   Взаимосвязь между этажами и площадью:
#
# *   floors (этажи) имеет положительную корреляцию с sqft_living и sqft_above, что логично, так как дома с большим количеством этажей обычно имеют большую площадь.
# 4.  Год постройки и год ремонта:
#
# *   yr_built (год постройки) и yr_renovated (год ремонта) имеют слабую отрицательную корреляцию, что может означать, что более старые дома чаще подвергались ремонту.
# 5.  Слабая корреляция с количеством спален:
#
# *   bedrooms (спальни) имеет относительно слабую корреляцию с другими параметрами, что может указывать на то, что количество спален само по себе не является сильным индикатором стоимости или качества дома.

# %%
df1 = pd.read_csv('/content/sample_data/laptop_price.csv', encoding = 'latin1')
df1.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...
